# %% [markdown]
# Os comandos abaixo carregam o famoso dataset do titanic no objeto chamado *df*. Explore a tabela e responda as seguintes questões **sempre colocando o código em Python utilizado para chegar às respostas.**
#
# 1) Quantas pessoas sobreviveram ao acidente?
# 2) Quantas criancas menores de 12 anos sobreviveram ao acidente?
# 3) Quantas pessoas embarcaram nos portos de Southampton OU Queenstow?
# 4) Crie um objeto chamado **passageiras** que seleciona somente as passageiras.
# 5) Crie um objeto chamado **criancas_cherbourg** que seleciona as crianças com menos de 12 anos E que embarcaram na cidade de Cherbourg.
# 6) Crie um objeto chamado **titanic_menor** e selecione as colunas de *nome*, *idade*, *classe* e *embarque*
# 7) Supondo que o valor da tarifa no dataset está em libras, e que 1£ = R$ 6.43, crie uma nova coluna chamada **tarifa_real** que contenha a tarifa de embarque em reais.
# 8) Agrupe pela coluna sobreviveu e calcule o número de passageiros por grupo (sim/nao)
# 9) Agrupe pelo local de embarque e calcule a média e a mediana da tarifa de cada grupo.
# 10) Agrupe pela classe e conte a quantidade de pessoas por classe
# 11) Agrupe pela classe e pela coluna sobreviveu e conte a quantidade de pessoas que sobreviveu de acordo com cada classe. Quem sobreviveu mais? A classe mais alta ou a mais baixa?
# 12) Agrupe pelo sexo e pela coluna sobreviveu e conte a quantidade de pessoas que sobreviveram de acordo com o sexo. Quem sobreviveu mais? Homens ou mulheres?

# %%
import pandas as pd

# %%
df = pd.read_csv('../dados/titanic.csv')
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:706, in PlainTextFormatter.__call__(self, obj)
#     699 stream = StringIO()
#     700 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     701     self.max_width, self.newline,
#     702     max_seq_length=self.max_seq_length,
#     703     singleton_pprinters=self.singleton_printers,
#     704     type_pprinters=self.type_printers,
#     705     deferred_pprinters=self.deferred_printers)
# --> 706 printer.pretty(obj)
#     707 printer.flush()
#     708 return stream.getvalue()
#
# File ~/.local/lib/python3.10/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~/.local/lib/python3.10/site-packages/IPython/lib/pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1063, in DataFrame.__repr__(self)
#    1060     return buf.getvalue()
#    1062 repr_params = fmt.get_dataframe_repr_params()
# -> 1063 return self.to_string(**repr_params)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1244, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1225 with option_context("display.max_colwidth", max_colwidth):
#    1226     formatter = fmt.DataFrameFormatter(
#    1227         self,
#    1228         columns=columns,
#    (...)
#    1242         decimal=decimal,
#    1243     )
# -> 1244     return fmt.DataFrameRenderer(formatter).to_string(
#    1245         buf=buf,
#    1246         encoding=encoding,
#    1247         line_width=line_width,
#    1248     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1606, in FloatArrayFormatter._format_strings(self)
#    1605 def _format_strings(self) -> list[str]:
# -> 1606     return list(self.get_result_as_array())
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1523, in FloatArrayFormatter.get_result_as_array(self)
#    1520     return formatted
#    1522 if self.formatter is not None:
# -> 1523     return format_with_na_rep(self.values, self.formatter, self.na_rep)
#    1525 if self.fixed_width:
#    1526     threshold = get_option("display.chop_threshold")
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1515, in FloatArrayFormatter.get_result_as_array.<locals>.format_with_na_rep(values, formatter, na_rep)
#    1512 def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str):
#    1513     mask = isna(values)
#    1514     formatted = np.array(
# -> 1515         [
#    1516             formatter(val) if not m else na_rep
#    1517             for val, m in zip(values.ravel(), mask.ravel())
#    1518         ]
#    1519     ).reshape(values.shape)
#    1520     return formatted
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1516, in <listcomp>(.0)
#    1512 def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str):
#    1513     mask = isna(values)
#    1514     formatted = np.array(
#    1515         [
# -> 1516             formatter(val) if not m else na_rep
#    1517             for val, m in zip(values.ravel(), mask.ravel())
#    1518         ]
#    1519     ).reshape(values.shape)
#    1520     return formatted
#
# ValueError: Invalid format specifier
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:342, in BaseFormatter.__call__(self, obj)
#     340     method = get_real_method(obj, self.print_method)
#     341     if method is not None:
# --> 342         return method()
#     343     return None
#     344 else:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1105, in DataFrame._repr_html_(self)
#    1083     show_dimensions = get_option("display.show_dimensions")
#    1085     formatter = fmt.DataFrameFormatter(
#    1086         self,
#    1087         columns=None,
#    (...)
#    1103         decimal=".",
#    1104     )
# -> 1105     return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1106 else:
#    1107     return None
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1110, in DataFrameRenderer.to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1101 Klass = NotebookFormatter if notebook else HTMLFormatter
#    1103 html_formatter = Klass(
#    1104     self.fmt,
#    1105     classes=classes,
#    (...)
#    1108     render_links=render_links,
#    1109 )
# -> 1110 string = html_formatter.to_string()
#    1111 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/html.py:77, in HTMLFormatter.to_string(self)
#      76 def to_string(self) -> str:
# ---> 77     lines = self.render()
#      78     if any(isinstance(x, str) for x in lines):
#      79         lines = [str(x) for x in lines]
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/html.py:632, in NotebookFormatter.render(self)
#     630 self.write("<div>")
#     631 self.write_style()
# --> 632 super().render()
#     633 self.write("</div>")
#     634 return self.elements
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/html.py:83, in HTMLFormatter.render(self)
#      82 def render(self) -> list[str]:
# ---> 83     self._write_table()
#      85     if self.should_show_dimensions:
#      86         by = chr(215)  # ×
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/html.py:258, in HTMLFormatter._write_table(self, indent)
#     255 if self.fmt.header or self.show_row_idx_names:
#     256     self._write_header(indent + self.indent_delta)
# --> 258 self._write_body(indent + self.indent_delta)
#     260 self.write("</table>", indent)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/html.py:406, in HTMLFormatter._write_body(self, indent)
#     404 def _write_body(self, indent: int) -> None:
#     405     self.write("<tbody>", indent)
# --> 406     fmt_values = self._get_formatted_values()
#     408     # write values
#     409     if self.fmt.index and isinstance(self.frame.index, MultiIndex):
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/html.py:596, in NotebookFormatter._get_formatted_values(self)
#     595 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 596     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/html.py:596, in <dictcomp>(.0)
#     595 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 596     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1606, in FloatArrayFormatter._format_strings(self)
#    1605 def _format_strings(self) -> list[str]:
# -> 1606     return list(self.get_result_as_array())
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1523, in FloatArrayFormatter.get_result_as_array(self)
#    1520     return formatted
#    1522 if self.formatter is not None:
# -> 1523     return format_with_na_rep(self.values, self.formatter, self.na_rep)
#    1525 if self.fixed_width:
#    1526     threshold = get_option("display.chop_threshold")
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1515, in FloatArrayFormatter.get_result_as_array.<locals>.format_with_na_rep(values, formatter, na_rep)
#    1512 def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str):
#    1513     mask = isna(values)
#    1514     formatted = np.array(
# -> 1515         [
#    1516             formatter(val) if not m else na_rep
#    1517             for val, m in zip(values.ravel(), mask.ravel())
#    1518         ]
#    1519     ).reshape(values.shape)
#    1520     return formatted
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1516, in <listcomp>(.0)
#    1512 def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str):
#    1513     mask = isna(values)
#    1514     formatted = np.array(
#    1515         [
# -> 1516             formatter(val) if not m else na_rep
#    1517             for val, m in zip(values.ravel(), mask.ravel())
#    1518         ]
#    1519     ).reshape(values.shape)
#    1520     return formatted
#
# ValueError: Invalid format specifier

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_passageiro   891 non-null    int64
#  1   sobreviveu      891 non-null    object
#  2   classe          891 non-null    int64
#  3   nome            891 non-null    object
#  4   sexo            891 non-null    object
#  5   idade           714 non-null    float64
#  6   irmaos_conjuge  891 non-null    int64
#  7   pais_criancas   891 non-null    int64
#  8   passagem        891 non-null    object
#  9   tarifa          891 non-null    float64
#  10  cabine          204 non-null    object
#  11  embarque        889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
# EX 1
# 342 pessoas sobreviveram
df['sobreviveu'].value_counts()
# Out:
# nao    549
# sim    342
# Name: sobreviveu, dtype: int64

# %%
# Vou preencher os valores nulos com um valor que eu possa filtrar e lembrar
df['idade'] = df['idade'].fillna(9999)
df['idade'].isna().sum()
df['idade'] = df['idade'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_passageiro   891 non-null    int64
#  1   sobreviveu      891 non-null    object
#  2   classe          891 non-null    int64
#  3   nome            891 non-null    object
#  4   sexo            891 non-null    object
#  5   idade           891 non-null    int64
#  6   irmaos_conjuge  891 non-null    int64
#  7   pais_criancas   891 non-null    int64
#  8   passagem        891 non-null    object
#  9   tarifa          891 non-null    float64
#  10  cabine          204 non-null    object
#  11  embarque        889 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 83.7+ KB

# %%
# EX 2
len(df.loc[(df['sobreviveu'] == 'sim') & (df['idade'] < 12)])
# Out:
# 39

# %%
# EX 3
len(df.loc[(df['embarque'] == 'Southampton') | (df['embarque'] == 'Queenstow')])
# Out:
# 721

# %%
# EX 4
passageiras = df.loc[(df['sexo'] == 'feminino')]
passageiras
# Out:
#      id_passageiro sobreviveu  classe  \
# 1                2        sim       1
# 2                3        sim       3
# 3                4        sim       1
# 8                9        sim       3
# 9               10        sim       2
# ..             ...        ...     ...
# 880            881        sim       2
# 882            883        nao       3
# 885            886        nao       3
# 887            888        sim       1
# 888            889        nao       3
#
#                                                   nome      sexo  idade  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  feminino     38
# 2                               Heikkinen, Miss. Laina  feminino     26
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  feminino     35
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  feminino     27
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  feminino     14
# ..                                                 ...       ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  feminino     25
# 882                       Dahlberg, Miss. Gerda Ulrika  feminino     22
# 885               Rice, Mrs. William (Margaret Norton)  feminino     39
# 887                       Graham, Miss. Margaret Edith  feminino     19
# 888           Johnston, Miss. Catherine Helen "Carrie"  feminino   9999
#
#      irmaos_conjuge  pais_criancas          passagem      tarifa cabine  \
# 1                 1              0          PC 17599     71.2833    C85
# 2                 0              0  STON/O2. 3101282   7925.0000    NaN
# 3                 1              0            113803     53.1000   C123
# 8                 0              2            347742     11.1333    NaN
# 9                 1              0            237736     30.0708    NaN
# ..              ...            ...               ...         ...    ...
# 880               0              1            230433     26.0000    NaN
# 882               0              0              7552     10.5167    NaN
# 885               0              5            382652  29125.0000    NaN
# 887               0              0            112053     30.0000    B42
# 888               1              2        W./C. 6607     23.4500    NaN
#
#         embarque
# 1      Cherbourg
# 2    Southampton
# 3    Southampton
# 8    Southampton
# 9      Cherbourg
# ..           ...
# 880  Southampton
# 882  Southampton
# 885    Queenstow
# 887  Southampton
# 888  Southampton
#
# [314 rows x 12 columns]

# %%
# EX 5
criancas_cherbourg = df.loc[(df['idade']< 12) & (df['embarque'] == 'Cherbourg')]
criancas_cherbourg
# Out:
#      id_passageiro sobreviveu  classe  \
# 43              44        sim       2
# 381            382        sim       3
# 448            449        sim       3
# 469            470        sim       3
# 644            645        sim       3
# 691            692        sim       3
# 731            732        nao       3
# 803            804        sim       3
# 827            828        sim       2
# 852            853        nao       3
#
#                                          nome       sexo  idade  \
# 43   Laroche, Miss. Simonne Marie Anne Andree   feminino      3
# 381               Nakid, Miss. Maria ("Mary")   feminino      1
# 448            Baclini, Miss. Marie Catherine   feminino      5
# 469             Baclini, Miss. Helene Barbara   feminino      0
# 644                    Baclini, Miss. Eugenie   feminino      0
# 691                        Karun, Miss. Manca   feminino      4
# 731                  Hassan, Mr. Houssein G N  masculino     11
# 803           Thomas, Master. Assad Alexander  masculino      0
# 827                     Mallet, Master. Andre  masculino      1
# 852                   Boulos, Miss. Nourelain   feminino      9
#
#      irmaos_conjuge  pais_criancas         passagem   tarifa cabine   embarque
# 43                1              2    SC/Paris 2123  41.5792    NaN  Cherbourg
# 381               0              2             2653  15.7417    NaN  Cherbourg
# 448               2              1             2666  19.2583    NaN  Cherbourg
# 469               2              1             2666  19.2583    NaN  Cherbourg
# 644               2              1             2666  19.2583    NaN  Cherbourg
# 691               0              1           349256  13.4167    NaN  Cherbourg
# 731               0              0             2699  18.7875    NaN  Cherbourg
# 803               0              1             2625   8.5167    NaN  Cherbourg
# 827               0              2  S.C./PARIS 2079  37.0042    NaN  Cherbourg
# 852               1              1             2678  15.2458    NaN  Cherbourg

# %%
# EX 6
titanic_menor = df.loc[:,['nome','idade','classe','embarque']]
titanic_menor
# Out:
#                                                   nome  idade  classe  \
# 0                              Braund, Mr. Owen Harris     22       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     38       1
# 2                               Heikkinen, Miss. Laina     26       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     35       1
# 4                             Allen, Mr. William Henry     35       3
# ..                                                 ...    ...     ...
# 886                              Montvila, Rev. Juozas     27       2
# 887                       Graham, Miss. Margaret Edith     19       1
# 888           Johnston, Miss. Catherine Helen "Carrie"   9999       3
# 889                              Behr, Mr. Karl Howell     26       1
# 890                                Dooley, Mr. Patrick     32       3
#
#         embarque
# 0    Southampton
# 1      Cherbourg
# 2    Southampton
# 3    Southampton
# 4    Southampton
# ..           ...
# 886  Southampton
# 887  Southampton
# 888  Southampton
# 889    Cherbourg
# 890    Queenstow
#
# [891 rows x 4 columns]

# %%
df['tarifa_real'] = df['tarifa']*6.43
